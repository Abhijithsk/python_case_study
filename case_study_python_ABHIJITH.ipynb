# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhijithsk/python_case_study/blob/main/case_study_python_ABHIJITH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employees = [
    {"id":101, "name":"Alice", "department":"Data", "salary":65000, "rating":4.5},
    {"id":102, "name":"Bob", "department":"AI", "salary":72000, "rating":4.8},
    {"id":103, "name":"Charlie", "department":"Web", "salary":58000, "rating":3.9},
    {"id":104, "name":"David", "department":"Data", "salary":61000, "rating":4.2},
    {"id":105, "name":"Eva", "department":"AI", "salary":75000, "rating":4.9},
    {"id":106, "name":"Frank", "department":"Cloud", "salary":68000, "rating":4.1},
    {"id":107, "name":"Grace", "department":"Web", "salary":59000, "rating":3.8},
    {"id":108, "name":"Helen", "department":"Data", "salary":70000, "rating":4.6}
]

#1.
print(f"Total Employees: {len(employees)}")

#2.
total_salary=0

for employee in employees:
  total_salary+=employee["salary"]

average_salary=total_salary/total_employees

highest_salary=employees[0]["salary"]
lowest_salary=employees[0]["salary"]

for employee in employees:
  if employee["salary"]>highest_salary:
    highest_salary=employee["salary"]

  if employee["salary"]<lowest_salary:
    lowest_salary=employee["salary"]

print("\nAverage Salary:", average_salary)
print("Highest Salary:", highest_salary)
print("Lowest Salary:", lowest_salary)

#3.
print("\nEmployees with Salary > 65000 and Rating >= 4.5")

for employee in employees:
  if employee["salary"]>65000 and employee["rating"]>=4.5:
    print(employee["name"])

#4.
print("\nEmployee Dictionary")
employee_dictionary={101: 'Alice', 102: 'Bob', 103: 'Charlie',
               104: 'David', 105: 'Eva', 106: 'Frank', 107: 'Grace',
               108: 'Helen'}
print(employee_dictionary)
#5.
names=[]

for employee in employees:
  names.append(employee["name"])

names.sort()
names.reverse()

print("\nFirst Three Employee Names")

for name in names[:3]:
  print(name)
#6.
employee_ids=[]

for employee in employees:
  employee_ids.append(employee["id"])

employee_ids=tuple(employee_ids)

print("\nEmployee ID Tuple")
print(employee_ids)

print("Maximum Employee ID:", max(employee_ids))
print("Minimum Employee ID:", min(employee_ids))

#7.
departments=set()

for employee in employees:
  departments.add(employee["department"])

print("\nDepartments")
print(departments)

#8.
search_id=int(input("\nEnter Employee ID: "))

found=False

for employee in employees:
  if employee["id"]==search_id:
    print("\nEmployee Found")
    print("ID:", employee["id"])
    print("Name:", employee["name"])
    print("Department:", employee["department"])
    print("Salary:", employee["salary"])
    print("Rating:", employee["rating"])

    found=True
    break

if found==False:
  print("\nEmployee Not Found")
# Out:
# Total Employees: 8
#
# Average Salary: 66000.0
# Highest Salary: 75000
# Lowest Salary: 58000
#
# Employees with Salary > 65000 and Rating >= 4.5
# Bob
# Eva
# Helen
#
# Employee Dictionary
# {101: 'Alice', 102: 'Bob', 103: 'Charlie', 104: 'David', 105: 'Eva', 106: 'Frank', 107: 'Grace', 108: 'Helen'}
#
# First Three Employee Names
# Helen
# Grace
# Frank
#
# Employee ID Tuple
# (101, 102, 103, 104, 105, 106, 107, 108)
# Maximum Employee ID: 108
# Minimum Employee ID: 101
#
# Departments
# {'AI', 'Data', 'Cloud', 'Web'}
#
# Enter Employee ID: 102
#
# Employee Found
# ID: 102
# Name: Bob
# Department: AI
# Salary: 72000
# Rating: 4.8
